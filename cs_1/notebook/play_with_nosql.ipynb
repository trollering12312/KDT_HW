# %%
import requests
from random import randint
import csv
from pymongo import MongoClient

# %% [markdown]
# ## Jupyter test

# %%
print('hello')
# Out:
# hello

# %%
response = requests.get('https://www.google.com/')
response.status_code
# Out:
# 200

# %%
response.text[:300]
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="dKGzA4Za/zGBKrHe'

# %% [markdown]
# ## Connect MongoDB

# %% [markdown]
# ### 이렇게!!
#
# $y=x+1$

# %%
# MongoDB Cloud Configs
# !Important
# Don't upload these configs
mongo_user = "yc12312"
mongo_pw= "2NNTT6kY6fdcNSj"
mongo_uri = f"mongodb+srv://{mongo_user}:{mongo_pw}@cluster0.a1ydk.mongodb.net/myFirstDatabase?retryWrites=true&w=majority"

# %%
# MongoDB Client 시작
client = MongoClient(mongo_uri)

# %%
# Pass if this code raise exception.(Print collection list)
client.cluster0.list_collection_names()
# Out:
# ['airlines', 'airports', 'users']

# %%
# set alias client.cluster0 to db
db = client.cluster0

# %%
# Create new collection
user_collection = db["users"]

# %%
# 무시하고 넘어갑시다^^ 해당 오류는 확인해볼게요^^
db.list_collection_names()
# Out:
# ['users']

# %% [markdown]
# ## Insert data

# %%
# INSERT 1 document
user1 = {
    "name":"John Doe",
    "email":"johndoe@gmail.com",
}

user_collection.insert_one(user1)

# %%
# INSERT lots of documents
many_users = [
    {
    "name":"Jane Doe",
    "email":"janedoe@gmail.com",
    },
    {
    "name":"Richard Doe",
    "email":"ritchedoe@gmail.com",
    },
    {
    "name":"John Poe",
    "email":"johnpoe@gmail.com",
    },
]
user_collection.insert_many(many_users)

# %% [markdown]
# ## Select data

# %%
# SELECT * FROM users;

query = {}
user_collection.find(query)

# %%
# to see the result, type casting done Cursor to list.
list(user_collection.find(query))

# %%
# To exclude some key,value, set value to 0 with key
list(user_collection.find(query, {"_id":0, "email":0, }))

# %%
# individual document(locale only at user2)
user2 = {
    "name":"John Stiles",
    "email":"jonny@gmail.com",
    "locale":"Seoul, KR",
}
user_collection.insert_one(user2)

# %%
query={}
list(user_collection.find(query, {"_id":0}))

# %%
# pymongo with python
[(item["email"][:-10], item["name"]) for item in user_collection.find({},{"_id":0})]

# %%
query={}
user_collection.find_one(query)

# %%
# SELECT * FROM users WHERE name is Jane Doe;
query={"name":"Jane Doe"}
list(user_collection.find(query, {"_id":0}))

# %%
# aggregation
query={"name":{"$regex":"^J"}}
list(user_collection.find(query, {"_id":0}))

# %% [markdown]
# ## Update data

# %%
# define set_age to return random integer 19-50
def set_age():
    return randint(19,50)

# %%
# update document where name is Jane Doe
query={"name":"Jane Doe"}
new_value={"$set":{"age":set_age()}}

user_collection.update_one(query, new_value)
user_collection.find_one(query)

# %%
# update documents to all
# For Jane Doe, update age.
for user in user_collection.find({}, {"_id":0}):
    new_value = {"$set":{"age":set_age()}}
    query = {"name":user["name"]}
    
    user_collection.update_one(query, new_value)

# %%
list(user_collection.find({},{"_id":0}))

# %% [markdown]
# ## Filter, Sort

# %%
# filter
# SELECT * FROM users WHERE age > 35;
query={"age":{"$lt":35}}
list(user_collection.find(query, {"_id":0}))

# %%
# SORT BY ASC(1) DESC(-1)
query={"age":{"$lt":35}}
list(user_collection.find(query, {"_id":0}).sort("age",-1))

# %%
list(user_collection.find({},{"_id":0}).sort("name", 1))

# %% [markdown]
# # Homework
#
# ## Export csv data to MongoDB

# %%
import csv # import csv module


with open('../data/airport_code.csv', encoding='cp949') as f:
    csv_reader = csv.reader(f, delimiter=',') # read csv file with csv.reader
    
    result = [] # result list
    
    next(csv_reader, None) # To skip csv header
    # ['영문명', '한글명', 'IATA코드', 'ICAO코드']
    for row in csv_reader:
        row_to_json = {
            'enName': row[0],
            'koName': row[1],
            'IATACode': row[2],
            'ICAOCode': row[3],
        }
        result.append(row_to_json)

# %%
#새 컬렉션 생성
airport_collection = db["airports"]

# %%
#컬렉션에 데이터 추가
airport_collection.insert_many(result)

# %%
#저장된 정보 출력

list(airport_collection.find({}, {"_id":0})) #id 제외
# Out:
# [{'enName': 'A Coruna Airport',
#   'koName': '아코루냐 공항',
#   'IATACode': 'LCG',
#   'ICAOCode': 'LECO',
#   'continent': '유럽',
#   'enCityName': 'A Coruna',
#   'enCountryName': 'Spain',
#   'koCountryName': '스페인'},
#  {'enName': 'A. De Barros Airport',
#   'koName': '닥터 아드헤마르 데 바로 공항',
#   'IATACode': 'PPB',
#   'ICAOCode': 'SBDN',
#   'continent': '중남미',
#   'enCityName': 'Presidente Prudente',
#   'enCountryName': 'Brazil',
#   'koCountryName': '브라질'},
#  {'enName': 'A. Neto Airport',
#   'koName': 'A. 네토 공항',
#   'IATACode': 'PNR',
#   'ICAOCode': 'FCPP',
#   'continent': '아프리카',
#   'enCityName': 'Pointe Noire',
#   'enCountryName': 'Democratic Republic of Congo',
#   'koCountryName': '콩고 민주공화국'},
#  {'enName': 'Aalborg Airport',
#   'koName': '올보르 공항',
#   'IATACode': 'AAL',
#   'ICAOCode': 'EKYT',
#   'continent': '유럽',
#   'enCityName': 'Aalborg',
#   'enCountryName': 'Denmark',
#   'koCountryName': '덴마크'},
#  {'enName': 'Aaro Airport',
#   'koName': '아로 공항',
#   'IATACode': 'MOL',
#   'ICAOCode': 'ENML',
#   'continent': '유럽',
#   'enCityName': 'Molde',
#   'enCountryName': 'Norway',
#   'koCountryName': '노르웨이'},
#  {'enName': 'Aba Tenna D. Yilma Airport',
#   'koName': '아바 테나 D. 일마 공항',
#   'IATACode': 'DIR',
#   'ICAOCode': 'HADR',
#   'continent': '아프리카',
#   'enCityName': 'Dire Dawa',
#   'enCountryName': 'Ethiopia',
#   'koCountryName': '이디오피아'},
#  {'enName': 'Abadan Airport',
#   'koName': '아바단 공항',
#   'IATACode': 'ABD',
#   'ICAOCode': 'OIAA',
#   'continent': '중동',
#   'enCityName': 'Abadan',
#   'enCountryName': 'Iran',
#   'koCountryName': '이란'},
#  {'enName': 'Abakan Airport',
#   'koName': '아바칸 공항',
#   'IATACode': 'ABA',
#   'ICAOCode': 'UNAA',
#   'continent': '유럽',
#   'enCityName': 'Abakan',
#   'enCountryName': 'Russia',
#   'koCountryName': '러시아'},
#  {'enName': 'Abbotsford International Airport',
#   'koName': '애보트포드 국제공항',
#   'IATACode': 'YXX',
#   'ICAOCode': 'CYXX',
#   'continent': '북미',
#   'enCityName': 'AbbotsfordBC',
#   'enCountryName': 'Canada',
#   'koCountryName': '캐나다'},
#  {'enName': 'Abha Regional Airport',
#   'koName': '아바 지역공항',
#   'IATACode': 'AHB',
#   'ICAOCode': 'OEAB',
#   'continent': '중동',
#   'enCityName': 'Abha',
#   'enCountryName': 'Saudi Arabia',
#   'koCountryName': '사우디아라비아'},
#  {'enName': 'Abilene Municipal Airport',
#   'koName': '애빌린 시공항',
#   'IATACode': 'ABI',
#   'ICAOCode': 'KABI',
#   'continent': '북미',
#   'enCityName': 'AbileneTX',
#   'enCountryName': 'United States',
#   'koCountryName': '미국'},
#  {'enName': 'Abraham Lincoln Capital Airport',
#   'koName': '에이브람 링컨 캐피톨 공항',
#   'IATACode': 'SPI',
#   'ICAOCode': 'KSPI',
#   'continent': '북미',
#   'enCityName': 'Springfield IL',
#   'enCountryName': 'United States',
#   'koCountryName': '미국'},
#  {'enName': 'Abruzzo International Airport ',
#   'koName': '우브르조 국제공항 ',
#   'IATACode': 'PSR',
#   'ICAOCode': 'LIBP',
#   'continent': '유럽',
#   'enCityName': 'Pescara',
#   'enCountryName': 'Italy',
#   'koCountryName': '이탈리아'},
#  {'enName': 'Abu Dhabi International Airport',
#   'koName': '아부다비 국제공항',
#   'IATACode': 'AUH',
#   'ICAOCode': 'OMAA',
#   'continent': '중동',
#   'enCityName': 'Abu Dhabi',
#   'enCountryName': 'United Arab Emirates',
#   'koCountryName': 'UAE'},
#  {'enName': 'Abu Musa Airport',
#   'koName': '아부 무사 공항',
#   'IATACode': 'AEU',
#   'ICAOCode': 'OIBA',
#   'continent': '중동',
#   'enCityName': 'AbuMousa',
#   'enCountryName': 'Iran',
#   'koCountryName': '이란'},
#  {'enName': 'Abu Simbel Airport',
#   'koName': '아부심벨 공항',
#   'IATACode': 'ABS',
#   'ICAOCode': 'HEBL',
#   'continent': '아프리카',
#   'enCityName': 'AbuSimbel',
#   'enCountryName': 'Egypt',
#   'koCountryName': '이집트'},
#  {'enName': 'Abuja International Airport',
#   'koName': '아부자 국제공항',
#   'IATACode': 'ABV',
#   'ICAOCode': 'DNAA',
#   'continent': '아프리카',
#   'enCityName': 'Abuja',
#   'enCountryName': 'Nigeria',
#   'koCountryName': '나이지리아'},
#  {'enName': 'Acandi Airport',
#   'koName': '아칸디 공항',
#   'IATACode': 'ACD',
#   'ICAOCode': 'SKAD',
#   'continent': '중남미',
#   'enCityName': 'Acandi',
#   'enCountryName': 'Colombia',
#   'koCountryName': '콜롬비아'},
#  {'enName': 'Achmad Yani Airport',
#   'koName': '아츠마드 야니 공항',
#   'IATACode': 'SRG',
#   'ICAOCode': 'WARS',
#   'continent': '아시아',
#   'enCityName': 'Semarang',
#   'enCountryName': 'Indonesia',
#   'koCountryName': '인도네시아'},
#  {'enName': 'Adampur Airport',
#   'koName': '아담푸르 공항',
#   'IATACode': 'AIP',
#   'ICAOCode': 'VIAX',
#   'continent': '아시아',
#   'enCityName': 'Adampur',
#   'enCountryName': 'India',
#   'koCountryName': '인도'},
#  {'enName': 'Adana Airport',
#   'koName': '아다나 공항',
#   'IATACode': 'ADA',
#   'ICAOCode': 'LTAF',
#   'continent': '유럽',
#   'enCityName': 'Adana',
#   'enCountryName': 'Turkey',
#   'koCountryName': '터키'},
#  {'enName': 'Adelaide International Airport',
#   'koName': '애들레이드 국제공항',
#   'IATACode': 'ADL',
#   'ICAOCode': 'YPAD',
#   'continent': '대양주',
#   'enCityName': 'Adelaide',
#   'enCountryName': 'Australia',
#   'koCountryName': '오스트레일리아'},
#  {'enName': 'Adisumarmo International Airport',
#   'koName': '아디 수마르모 국제공항',
#   'IATACode': 'SOC',
#   'ICAOCode': 'WARQ',
#   'continent': '아시아',
#   'enCityName': 'Surakarta',
#   'enCountryName': 'Indonesia',
#   'koCountryName': '인도네시아'},
#  {'enName': 'Adisutjipto Airport',
#   'koName': '아디숫집토 공항',
#   'IATACode': 'JOG',
#   'ICAOCode': 'WARJ',
#   'continent': '아시아',
#   'enCityName': 'Yogyakarta',
#   'enCountryName': 'Indonesia',
#   'koCountryName': '인도네시아'},
#  {'enName': 'Adiyaman Airport',
#   'koName': '아디야만 공항',
#   'IATACode': 'ADF',
#   'ICAOCode': 'LTCP',
#   'continent': '유럽',
#   'enCityName': 'Adiyaman',
#   'enCountryName': 'Turkey',
#   'koCountryName': '터키'},
#  {'enName': 'Adler Sochi International Airport',
#   'koName': '아들라 소치 국제공항',
#   'IATACode': 'AER',
#   'ICAOCode': 'URSS',
#   'continent': '유럽',
#   'enCityName': 'Sochi',
#   'enCountryName': 'Russia',
#   'koCountryName': '러시아'},
#  {'enName': 'Adnan Menderes Airport',
#   'koName': '아드난 멘데레스 공항',
#   'IATACode': 'ADB',
#   'ICAOCode': 'LTBJ',
#   'continent': '유럽',
#   'enCityName': 'Izmir',
#   'enCountryName': 'Turkey',
#   'koCountryName': '터키'},
#  {'enName': 'Aerodrome de Meaux - Esbly',
#   'koName': 'Meaux - Esbly 공항',
#   'IATACode': 'XYB',
#   'ICAOCode': 'CSLA',
#   'continent': '유럽',
#   'enCityName': 'Meaux / Esbly',
#   'enCountryName': 'France',
#   'koCountryName': '프랑스'},
#  {'enName': 'Aeroparque Jorge Newbery Airport',
#   'koName': '아에르파크 호르헤 뉴베리 공항',
#   'IATACode': 'AEP',
#   'ICAOCode': 'SABE',
#   'continent': '중남미',
#   'enCityName': 'Buenos Aires',
#   'enCountryName': 'Argentina',
#   'koCountryName': '아르헨티나'},
#  {'enName': 'Aeroporto Internacional de Foz do Iguacu',
#   'koName': '이과수폭포 공항',
#   'IATACode': 'IGU',
#   'ICAOCode': 'SBFI',
#   'continent': '중남미',
#   'enCityName': 'Foz Do Iguagu',
#   'enCountryName': 'Brazil',
#   'koCountryName': '브라질'},
#  {'enName': 'Afonso Pena Airport',
#   'koName': '아폰소 페냐 공항',
#   'IATACode': 'CWB',
#   'ICAOCode': 'SBCT',
#   'continent': '중남미',
#   'enCityName': 'Curitiba',
#   'enCountryName': 'Brazil',
#   'koCountryName': '브라질'},
#  {'enName': 'Agatti Aerodrome',
#   'koName': '아가티 비행장',
#   'IATACode': 'AGX',
#   'ICAOCode': 'VOAT',
#   'continent': '아시아',
#   'enCityName': 'Agatti',
#   'enCountryName': 'India',
#   'koCountryName': '인도'},
#  {'enName': 'Agoncillo Airport',
#   'koName': '아곤칠로 공항',
#   'IATACode': 'RJL',
#   'ICAOCode': 'LERJ',
#   'continent': '유럽',
#   'enCityName': 'Logrono',
#   'enCountryName': 'Spain',
#   'koCountryName': '스페인'},
#  {'enName': 'Agri Airport',
#   'koName': '아리 공항',
#   'IATACode': 'AJI',
#   'ICAOCode': 'LTCO',
#   'continent': '유럽',
#   'enCityName': 'Agri',
#   'enCountryName': 'Turkey',
#   'koCountryName': '터키'},
#  {'enName': 'Aguni Airport',
#   'koName': '아구니 공항',
#   'IATACode': 'AGJ',
#   'ICAOCode': 'RORA',
#   'continent': '아시아',
#   'enCityName': 'Aguni',
#   'enCountryName': 'Japan',
#   'koCountryName': '일본'},
#  {'enName': 'Ahe Airport',
#   'koName': '아헤 공항',
#   'IATACode': 'AHE',
#   'ICAOCode': 'NTHE',
#   'continent': '대양주',
#   'enCityName': 'Ahe',
#   'enCountryName': 'French Plynesia',
#   'koCountryName': '프랑스령폴리네시아'},
#  {'enName': 'Ahwaz Airport',
#   'koName': '아와즈 공항',
#   'IATACode': 'AWZ',
#   'ICAOCode': 'OIAW',
#   'continent': '중동',
#   'enCityName': 'Ahvaz',
#   'enCountryName': 'Iran',
#   'koCountryName': '이란'},
#  {'enName': 'Ain Arnat Airport',
#   'koName': '아인 아낫 공항',
#   'IATACode': 'QSF',
#   'ICAOCode': 'DAAS',
#   'continent': '아프리카',
#   'enCityName': 'Setif',
#   'enCountryName': 'Algeria',
#   'koCountryName': '알제리'},
#  {'enName': 'Ain el Bey Airport',
#   'koName': '아인 엘 베이 공항',
#   'IATACode': 'CZL',
#   'ICAOCode': 'DABC',
#   'continent': '아프리카',
#   'enCityName': 'Constantine',
#   'enCountryName': 'Algeria',
#   'koCountryName': '알제리'},
#  {'enName': 'Aix Les Milles Airport',
#   'koName': '액스레밀 공항',
#   'IATACode': 'QXB',
#   'ICAOCode': 'LFMA',
#   'continent': '유럽',
#   'enCityName': 'Aix-en-Provence',
#   'enCountryName': 'France',
#   'koCountryName': '프랑스'},
#  {'enName': 'Ajaccio Napoleon bonarparte Airportirport ',
#   'koName': '아작시오 나폴레옹 보나파르트 공항 ',
#   'IATACode': 'AJA',
#   'ICAOCode': 'LFKJ',
#   'continent': '유럽',
#   'enCityName': 'Ajaccio',
#   'enCountryName': 'France',
#   'koCountryName': '프랑스'},
#  {'enName': 'Akanu Ibiam International Airport',
#   'koName': '아쿠누 이비암 국제공항',
#   'IATACode': 'ENU',
#   'ICAOCode': 'DNEN',
#   'continent': '아프리카',
#   'enCityName': 'Enugu',
#   'enCountryName': 'Nigeria',
#   'koCountryName': '나이지리아'},
#  {'enName': 'Akita Airport',
#   'koName': '아키타 공항',
#   'IATACode': 'AXT',
#   'ICAOCode': 'RJSK',
#   'continent': '아시아',
#   'enCityName': 'Akita',
#   'enCountryName': 'Japan',
#   'koCountryName': '일본'},
#  {'enName': 'Akron-Canton Regional Airport',
#   'koName': '애크런 캔튼 지역공항',
#   'IATACode': 'CAK',
#   'ICAOCode': 'KCAK',
#   'continent': '북미',
#   'enCityName': 'Akron OH',
#   'enCountryName': 'United States',
#   'koCountryName': '미국'},
#  {'enName': 'Aksu Airport',
#   'koName': '아커쑤 공항',
#   'IATACode': 'AKU',
#   'ICAOCode': 'ZWAK',
#   'continent': '아시아',
#   'enCityName': 'Akesu',
#   'enCountryName': 'China',
#   'koCountryName': '중국'},
#  {'enName': 'Aktion Airport',
#   'koName': '악티온 공항',
#   'IATACode': 'PVK',
#   'ICAOCode': 'LGPZ',
#   'continent': '유럽',
#   'enCityName': 'Preveza/Lefkas',
#   'enCountryName': 'Greece',
#   'koCountryName': '그리스'},
#  {'enName': 'Akure Airport',
#   'koName': '아쿠레 공항',
#   'IATACode': 'AKR',
#   'ICAOCode': 'DNAK',
#   'continent': '아프리카',
#   'enCityName': 'Akure',
#   'enCountryName': 'Nigeria',
#   'koCountryName': '나이지리아'},
#  {'enName': 'Akureyri Airport',
#   'koName': '아쿠레이리 공항',
#   'IATACode': 'AEY',
#   'ICAOCode': 'BIAR',
#   'continent': '유럽',
#   'enCityName': 'Akureyri',
#   'enCountryName': 'Iceland',
#   'koCountryName': '아이슬란드'},
#  {'enName': 'Al Ain International Airport',
#   'koName': '알아인 국제공항',
#   'IATACode': 'AAN',
#   'ICAOCode': 'OMAL',
#   'continent': '중동',
#   'enCityName': 'Al Ain',
#   'enCountryName': 'United Arab Emirates',
#   'koCountryName': 'UAE'},
#  {'enName': 'Al Alamain International Airport',
#   'koName': 'Al Alamain 국제 공항',
#   'IATACode': 'DBB',
#   'ICAOCode': 'HEAL[2]',
#   'continent': '아프리카',
#   'enCityName': 'El Dabaa',
#   'enCountryName': 'Egypt',
#   'koCountryName': '이집트'},
#  {'enName': 'Al Bateen Executive Airport',
#   'koName': '알바틴 특급공항',
#   'IATACode': 'AZI',
#   'ICAOCode': 'OMAD',
#   'continent': '중동',
#   'enCityName': 'ABU DHABI',
#   'enCountryName': 'United Arab Emirates',
#   'koCountryName': 'UAE'},
#  {'enName': 'Al Maktoum International Airport',
#   'koName': '알 막튬 국제공항',
#   'IATACode': 'DWC',
#   'ICAOCode': 'OMDW',
#   'continent': '중동',
#   'enCityName': 'Dubai',
#   'enCountryName': 'United Arab Emirates',
#   'koCountryName': 'UAE'},
#  {'enName': 'Al Massira Airport',
#   'koName': '알 마씨라 공항',
#   'IATACode': 'AGA',
#   'ICAOCode': 'GMAD',
#   'continent': '아프리카',
#   'enCityName': 'Agadir',
#   'enCountryName': 'Morocco',
#   'koCountryName': '모로코'},
#  {'enName': 'Al Wajh Domestic Airprot ',
#   'koName': '알 웨지 국내공항',
#   'IATACode': 'EJH',
#   'ICAOCode': 'OEWJ',
#   'continent': '중동',
#   'enCityName': 'Wedjh',
#   'enCountryName': 'Saudi Arabia',
#   'koCountryName': '사우디아라비아'},
#  {'enName': 'al-Ahsa Domestic Airport',
#   'koName': '알 아샤 국내공항',
#   'IATACode': 'HOF',
#   'ICAOCode': 'OEAH',
#   'continent': '중동',
#   'enCityName': 'Al-Ahsa',
#   'enCountryName': 'Saudi Arabia',
#   'koCountryName': '사우디아라비아'},
#  {'enName': 'Al-Aqiq Airport',
#   'koName': '알 아키크 공항',
#   'IATACode': 'ABT',
#   'ICAOCode': 'OEBA',
#   'continent': '중동',
#   'enCityName': 'Al-Baha',
#   'enCountryName': 'Saudi Arabia',
#   'koCountryName': '사우디아라비아'},
#  {'enName': 'Albacete Airport',
#   'koName': '알바세테 공항',
#   'IATACode': 'ABC',
#   'ICAOCode': 'LEAB',
#   'continent': '유럽',
#   'enCityName': 'Albacete',
#   'enCountryName': 'Spain',
#   'koCountryName': '스페인'},
#  {'enName': 'Albany Airport',
#   'koName': '올버니 공항',
#   'IATACode': 'ALH',
#   'ICAOCode': 'YABA',
#   'continent': '대양주',
#   'enCityName': 'Albany',
#   'enCountryName': 'Australia',
#   'koCountryName': '오스트레일리아'},
#  {'enName': 'Albany International Airport',
#   'koName': '올버니 국제공항',
#   'IATACode': 'ALB',
#   'ICAOCode': 'KALB',
#   'continent': '북미',
#   'enCityName': 'Albany NY',
#   'enCountryName': 'United States',
#   'koCountryName': '미국'},
#  {'enName': 'Albert - Bray Airport',
#   'koName': '앨버트 브라이 공항',
#   'IATACode': 'BYF',
#   'ICAOCode': 'LFAQ',
#   'continent': '유럽',
#   'enCityName': 'Albert',
#   'enCountryName': 'France',
#   'koCountryName': '프랑스'},
#  {'enName': 'Albuquerque International Sunport',
#   'koName': '앨버커키 국제선포트',
#   'IATACode': 'ABQ',
#   'ICAOCode': 'KABQ',
#   'continent': '북미',
#   'enCityName': 'Albuquerque NM',
#   'enCountryName': 'United States',
#   'koCountryName': '미국'},
#  {'enName': 'Albury Airport',
#   'koName': '엘버리 공항',
#   'IATACode': 'ABX',
#   'ICAOCode': 'YMAY',
#   'continent': '대양주',
#   'enCityName': 'Albury',
#   'enCountryName': 'Australia',
#   'koCountryName': '오스트레일리아'},
#  {'enName': 'Alejo Garcia Airport',
#   'koName': '알레죠 가르시아 공항',
#   'IATACode': 'AGT',
#   'ICAOCode': 'SGES',
#   'continent': '중남미',
#   'enCityName': 'Ciudad del Este',
#   'enCountryName': 'Paraguay',
#   'koCountryName': '파라과이'},
#  {'enName': 'Alex Papadiamantis Airport ',
#   'koName': '알렉스 파파디아만티스 ',
#   'IATACode': 'JSI',
#   'ICAOCode': 'LGSK',
#   'continent': '유럽',
#   'enCityName': 'Skiathos',
#   'enCountryName': 'Greece',
#   'koCountryName': '그리스'},
#  {'enName': 'Alexand the Great Airport ',
#   'koName': '알렉산더 더 그레이트 공항 ',
#   'IATACode': 'SKP',
#   'ICAOCode': 'LWSK',
#   'continent': '유럽',
#   'enCityName': 'Skopje',
#   'enCountryName': 'North Macedonia',
#   'koCountryName': '북마케도니아'},
#  {'enName': 'Alexandria International Airport',
#   'koName': '알렉산드리아 국제공항',
#   'IATACode': 'AEX',
#   'ICAOCode': 'KAEX',
#   'continent': '북미',
#   'enCityName': 'Alexandria LA',
#   'enCountryName': 'United States',
#   'koCountryName': '미국'},
#  {'enName': 'Alfonso Bonilla Aragon Airport',
#   'koName': '알폰손 보닐랴 아라곤 공항',
#   'IATACode': 'CLO',
#   'ICAOCode': 'SKCL',
#   'continent': '중남미',
#   'enCityName': 'Cali',
#   'enCountryName': 'Colombia',
#   'koCountryName': '콜롬비아'},
#  {'enName': 'Alfonso Lopez Pumarejo Airport',
#   'koName': '알폰소 로제즈 푸마레조 공항',
#   'IATACode': 'VUP',
#   'ICAOCode': 'SKVP',
#   'continent': '중남미',
#   'enCityName': 'Valledupar',
#   'enCountryName': 'Colombia',
#   'koCountryName': '콜롬비아'},
#  {'enName': 'Al-Fujairah International Airport',
#   'koName': '알푸자이라 국제공항',
#   'IATACode': 'FJR',
#   'ICAOCode': 'OMFJ',
#   'continent': '중동',
#   'enCityName': 'Fujairah',
#   'enCountryName': 'United Arab Emirates',
#   'koCountryName': 'UAE'},
#  {'enName': 'Algeciars',
#   'koName': '알헤시라스공항',
#   'IATACode': 'AEI',
#   'ICAOCode': 'LEAG',
#   'continent': '유럽',
#   'enCityName': 'Algeciras',
#   'enCountryName': 'Spain',
#   'koCountryName': '스페인'},
#  {'enName': 'Alicante Airport',
#   'koName': '알리칸테 공항',
#   'IATACode': 'ALC',
#   'ICAOCode': 'LEAL',
#   'continent': '유럽',
#   'enCityName': 'Alicante',
#   'enCountryName': 'Spain',
#   'koCountryName': '스페인'},
#  {'enName': 'Alice Springs Airport',
#   'koName': '앨리스 스프링스 공항',
#   'IATACode': 'ASP',
#   'ICAOCode': 'YBAS',
#   'continent': '대양주',
#   'enCityName': 'Alice Springs',
#   'enCountryName': 'Australia',
#   'koCountryName': '오스트레일리아'},
#  {'enName': 'al-Jouf Domestic Airport',
#   'koName': '알 주프 국내공항',
#   'IATACode': 'AJF',
#   'ICAOCode': 'OESK',
#   'continent': '중동',
#   'enCityName': 'Al-Jouf',
#   'enCountryName': 'Saudi Arabia',
#   'koCountryName': '사우디아라비아'},
#  {'enName': 'Allah Valley Airport',
#   'koName': '알라 밸리 공항',
#   'IATACode': 'AAV',
#   'ICAOCode': 'RPMA',
#   'continent': '아시아',
#   'enCityName': 'Surallah',
#   'enCountryName': 'Philippines',
#   'koCountryName': '필리핀'},
#  {'enName': 'Allama Iqbal International Airport',
#   'koName': '알라마 익발 국제공항',
#   'IATACode': 'LHE',
#   'ICAOCode': 'OPLA',
#   'continent': '아시아',
#   'enCityName': 'Lahore',
#   'enCountryName': 'Pakistan',
#   'koCountryName': '파키스탄'},
#  {'enName': 'Almaty Airport',
#   'koName': '알마티 공항',
#   'IATACode': 'ALA',
#   'ICAOCode': 'UAAA',
#   'continent': '아시아',
#   'enCityName': 'Almaty',
#   'enCountryName': 'Kazakhstan',
#   'koCountryName': '카자흐스탄'},
#  {'enName': 'Almeria International Airport',
#   'koName': '알메리아 국제공항',
#   'IATACode': 'LEI',
#   'ICAOCode': 'LEAM',
#   'continent': '유럽',
#   'enCityName': 'Almerta',
#   'enCountryName': 'Spain',
#   'koCountryName': '스페인'},
#  {'enName': 'Almirante Padilla Airport',
#   'koName': '알미란테 파딜랴 공항',
#   'IATACode': 'RCH',
#   'ICAOCode': 'SKRH',
#   'continent': '중남미',
#   'enCityName': 'Riohacha',
#   'enCountryName': 'Colombia',
#   'koCountryName': '콜롬비아'},
#  {'enName': 'Almirante Zar Airport',
#   'koName': '알미란테 챠르 공항',
#   'IATACode': 'REL',
#   'ICAOCode': 'SAVT',
#   'continent': '중남미',
#   'enCityName': 'Trelew',
#   'enCountryName': 'Argentina',
#   'koCountryName': '아르헨티나'},
#  {'enName': 'Alta Airport',
#   'koName': '알타 공항',
#   'IATACode': 'ALF',
#   'ICAOCode': 'ENAT',
#   'continent': '유럽',
#   'enCityName': 'Alta',
#   'enCountryName': 'Norway',
#   'koCountryName': '노르웨이'},
#  {'enName': 'Altamira Airport',
#   'koName': '알타미라 공항',
#   'IATACode': 'ATM',
#   'ICAOCode': 'SBHT',
#   'continent': '중남미',
#   'enCityName': 'Altamira',
#   'enCountryName': 'Brazil',
#   'koCountryName': '브라질'},
#  {'enName': 'Altay Airport',
#   'koName': '알타이 공항',
#   'IATACode': 'AAT',
#   'ICAOCode': 'ZWAT',
#   'continent': '아시아',
#   'enCityName': 'Aletai',
#   'enCountryName': 'China',
#   'koCountryName': '중국'},
#  {'enName': 'Alula Aba Airport',
#   'koName': '알류아 아바 공항',
#   'IATACode': 'MQX',
#   'ICAOCode': 'HAMK',
#   'continent': '아프리카',
#   'enCityName': 'Makale',
#   'enCountryName': 'Ethiopia',
#   'koCountryName': '이디오피아'},
#  {'enName': 'Alvarez International Airport ',
#   'koName': '알바레즈 국제공항 ',
#   'IATACode': 'ACA',
#   'ICAOCode': 'MMAA',
#   'continent': '중남미',
#   'enCityName': 'Acapulco',
#   'enCountryName': 'Mexico',
#   'koCountryName': '멕시코'},
#  {'enName': 'Alxa Left Banner Bayanhot Airport',
#   'koName': 'Alxa 레프트배너 Bayanhot 공항',
#   'IATACode': 'AXF',
#   'ICAOCode': '',
#   'continent': '아시아',
#   'enCityName': 'Bayanhot',
#   'enCountryName': 'China',
#   'koCountryName': '중국'},
#  {'enName': 'Alxa Right Banner Badanjilin Airport',
#   'koName': 'Alxa Right Banner 바탄 지린 공항',
#   'IATACode': 'RHT',
#   'ICAOCode': 'ZBAR',
#   'continent': '아시아',
#   'enCityName': 'Badanjilin',
#   'enCountryName': 'China',
#   'koCountryName': '중국'},
#  {'enName': 'Alyangula Airport',
#   'koName': '알리앵굴라 공항',
#   'IATACode': 'GTE',
#   'ICAOCode': 'YGTE',
#   'continent': '대양주',
#   'enCityName': 'Groote Eylandt',
#   'enCountryName': 'Australia',
#   'koCountryName': '오스트레일리아'},
#  {'enName': 'Amado Nervo National Airport',
#   'koName': '아마도 네르보 내셔널 공항',
#   'IATACode': 'TPQ',
#   'ICAOCode': 'MMEP',
#   'continent': '중남미',
#   'enCityName': 'Tepic',
#   'enCountryName': 'Mexico',
#   'koCountryName': '멕시코'},
#  {'enName': 'Amakusa Airfield',
#   'koName': '아마쿠사 비행장',
#   'IATACode': 'AXJ',
#   'ICAOCode': 'RJDA',
#   'continent': '아시아',
#   'enCityName': 'Amakusa',
#   'enCountryName': 'Japan',
#   'koCountryName': '일본'},
#  {'enName': 'Amami Airport',
#   'koName': '아마미 공항',
#   'IATACode': 'ASJ',
#   'ICAOCode': 'RJKA',
#   'continent': '아시아',
#   'enCityName': 'Amami',
#   'enCountryName': 'Japan',
#   'koCountryName': '일본'},
#  {'enName': 'Amasya Merzifon Airport',
#   'koName': '아마시야 메르지폰 공항',
#   'IATACode': 'MZH',
#   'ICAOCode': 'LTAP',
#   'continent': '유럽',
#   'enCityName': 'Amasya',
#   'enCountryName': 'Turkey',
#   'koCountryName': '터키'},
#  {'enName': 'Amausi Airport',
#   'koName': '아마우시 공항',
#   'IATACode': 'LKO',
#   'ICAOCode': 'VILK',
#   'continent': '아시아',
#   'enCityName': 'Lucknow',
#   'enCountryName': 'India',
#   'koCountryName': '인도'},
#  {'enName': 'Amborovy Airport',
#   'koName': '암보로비 공항',
#   'IATACode': 'MJN',
#   'ICAOCode': 'FMNM',
#   'continent': '아프리카',
#   'enCityName': 'Mahajanga',
#   'enCountryName': 'Madagascar',
#   'koCountryName': '마다가스카르'},
#  {'enName': 'Amiens - Glisy Airport',
#   'koName': '아미앵 글리시 공항',
#   'IATACode': 'QAM',
#   'ICAOCode': 'LFAY',
#   'continent': '유럽',
#   'enCityName': 'Amiens / Glisy',
#   'enCountryName': 'France',
#   'koCountryName': '프랑스'},
#  {'enName': 'Amilcar Cabral International Airport',
#   'koName': '아밀카르 카브럴 국제공항',
#   'IATACode': 'SID',
#   'ICAOCode': 'GVAC',
#   'continent': '아프리카',
#   'enCityName': 'Ilha Do Sal',
#   'enCountryName': 'Cabo Verde',
#   'koCountryName': '카보베르데'},
#  {'enName': 'Amman Civil - Marka Airport ',
#   'koName': '암만 시빌 마르카 공항',
#   'IATACode': 'ADJ',
#   'ICAOCode': 'OJAM',
#   'continent': '중동',
#   'enCityName': 'Amman',
#   'enCountryName': 'Jordan',
#   'koCountryName': '요르단'},
#  {'enName': 'Anaa Airport',
#   'koName': '아나 공항',
#   'IATACode': 'AAA',
#   'ICAOCode': 'NTGA',
#   'continent': '대양주',
#   'enCityName': 'Anaa',
#   'enCountryName': 'French Plynesia',
#   'koCountryName': '프랑스령폴리네시아'},
#  {'enName': 'Anadolu University Airport',
#   'koName': '아나둘루 유니버시티 공항',
#   'IATACode': 'AOE',
#   'ICAOCode': 'LTBY',
#   'continent': '유럽',
#   'enCityName': 'Eskisehir',
#   'enCountryName': 'Turkey',
#   'koCountryName': '터키'},
#  {'enName': 'Andoya Airport',
#   'koName': '안도야 공항',
#   'IATACode': 'ANX',
#   'ICAOCode': 'ENAN',
#   'continent': '유럽',
#   'enCityName': 'Andoya',
#   'enCountryName': 'Norway',
#   'koCountryName': '노르웨이'}]

# %% [markdown]
# ## Update airport info to MongoDB

# %%
with open('../data/airport_info.csv', encoding='cp949') as f:
    csv_info = csv.reader(f, delimiter=',')
    
    result = []
    
    next(csv_info, None) # to skip csv header 
    # ['영문명', '한글명', 'IATA코드', 'ICAO코드', '지역', '국가명_영문', '국가명_한글', '도시명_영문']
    for row in csv_info:
        to_json = {"$set":{
            'continent': row[4],
            'enCountryName': row[5],
            'koCountryName': row[6],
            'enCityName': row[7],
        }}
        #query를 기준으로 찾아 새로운 데이터 추가
        query = {'IATACode':row[2]}
        new_value = to_json
        try:
            airport_collection.update_one(query, new_value)
        except:
            print(f'not found {row[2]}')
            pass

# %% [markdown]
# # TODO
#
# 위의 코드를 참조하여 `../airline_code.csv`를 insert하고,  `../airline_info.csv`의 추가정보를 update하세요
#
# - IATA가 붙은 파일들은 원본파일입니다. 2534개라 다 insert 하면 daily limit 넘어갑니다
# - google colab 쓰시는 분들은 왼쪽 상단 browser에 csv 파일들을 업로드 한 후 디렉토리 위치에 맞게 경로를 수정하시면 가능합니다

# %%
#airline으로 실습

#insert
import csv # import csv module


with open('../data/airline_code.csv', encoding='cp949') as f:
    csv_reader = csv.reader(f, delimiter=',') # read csv file with csv.reader
    
    result = [] # result list
    
    next(csv_reader, None) # To skip csv header
    # 항공사(영문명) ,항공사(한글명), 항공사코드(IATA), 항공사코드(ICAO), 항공사상태

    for row in csv_reader:
        row_to_json = {
            'enName': row[0],
            'koName': row[1],
            'IATACode': row[2],
            'ICAOCode': row[3],
            'status' : row[4]
        }
        result.append(row_to_json)

airline_collection = db["airlines"]

airline_collection.insert_many(result)

# %%
list(airline_collection.find({}, {"_id":0})) #id 제외
# Out:
# [{'enName': '135 Airways',
#   'koName': '135 에어웨이',
#   'IATACode': '',
#   'ICAOCode': 'GNL',
#   'status': 'Grounded'},
#  {'enName': '1time',
#   'koName': '1타임항공',
#   'IATACode': '1T',
#   'ICAOCode': 'RNX',
#   'status': 'Grounded'},
#  {'enName': '2 Sqn, No 1 Elementary Flying Training School',
#   'koName': 'No 기초비행훈련스쿨 2편대',
#   'IATACode': '',
#   'ICAOCode': 'WYT',
#   'status': 'Grounded'},
#  {'enName': '21 Air',
#   'koName': '21 에어',
#   'IATACode': '2I',
#   'ICAOCode': 'CSB',
#   'status': 'Active'},
#  {'enName': '213 Flight Unit',
#   'koName': '213 비행대대',
#   'IATACode': '',
#   'ICAOCode': 'TFU',
#   'status': 'Grounded'},
#  {'enName': '223 Flight Unit, State Airline',
#   'koName': '223 비행대대, 스테이트 에어라인',
#   'IATACode': '',
#   'ICAOCode': 'CHD',
#   'status': 'Grounded'},
#  {'enName': '224th Flight Unit',
#   'koName': '224 비행대대',
#   'IATACode': '',
#   'ICAOCode': 'TTF',
#   'status': 'Grounded'},
#  {'enName': '247 Jet Ltd',
#   'koName': '247 제트',
#   'IATACode': '',
#   'ICAOCode': 'TWF',
#   'status': 'Grounded'},
#  {'enName': '32 (Tr) Squadron, Raf Northolt',
#   'koName': '영국공군 노솔트 32대대',
#   'IATACode': '',
#   'ICAOCode': 'NOH',
#   'status': 'Grounded'},
#  {'enName': '3D Aviation',
#   'koName': '3D 에비에이션',
#   'IATACode': '',
#   'ICAOCode': 'SEC',
#   'status': 'Grounded'},
#  {'enName': '3Grcomm Ltd (T/A Crest Aviation)',
#   'koName': '3G 알콤 - 크레스트 항공',
#   'IATACode': '',
#   'ICAOCode': 'CAN',
#   'status': 'Grounded'},
#  {'enName': '40 Mile Air',
#   'koName': '40마일에어',
#   'IATACode': 'Q5',
#   'ICAOCode': 'MLA',
#   'status': 'Active'},
#  {'enName': '43 Air School',
#   'koName': '43 비행스쿨',
#   'IATACode': '',
#   'ICAOCode': 'PIU',
#   'status': 'Grounded'},
#  {'enName': '4D Air',
#   'koName': '4D 에어',
#   'IATACode': '',
#   'ICAOCode': 'QRT',
#   'status': 'Grounded'},
#  {'enName': '540 Ghana Ltd.',
#   'koName': '540 가나',
#   'IATACode': '5G',
#   'ICAOCode': '',
#   'status': 'Active'},
#  {'enName': '611897 Alberta Ltd',
#   'koName': '611897 앨버타',
#   'IATACode': '',
#   'ICAOCode': 'THD',
#   'status': 'Active'},
#  {'enName': '748 Air Services',
#   'koName': '748 항공서비스',
#   'IATACode': '',
#   'ICAOCode': 'IHO',
#   'status': 'Active'},
#  {'enName': '84 Sqn Raf Akrotiri',
#   'koName': '아크로티리 공군 84연대',
#   'IATACode': '',
#   'ICAOCode': 'AKG',
#   'status': 'Grounded'},
#  {'enName': '9 Air',
#   'koName': '9 에어',
#   'IATACode': 'AQ',
#   'ICAOCode': 'JYH',
#   'status': 'Active'},
#  {'enName': '9G Rail Limited',
#   'koName': '9G 레일',
#   'IATACode': '9G',
#   'ICAOCode': '',
#   'status': 'Grounded'},
#  {'enName': 'AA 767, LLC',
#   'koName': 'aa 767',
#   'IATACode': '7Q',
#   'ICAOCode': '',
#   'status': 'Active'},
#  {'enName': 'AAA - Air Alps Aviation Ges.M.B.H.',
#   'koName': 'AAA - 에어알프스 항공',
#   'IATACode': 'A6',
#   'ICAOCode': 'LPV',
#   'status': 'Grounded'},
#  {'enName': 'AB Aviation',
#   'koName': 'AB 항공',
#   'IATACode': 'Y6',
#   'ICAOCode': 'CYK',
#   'status': 'Grounded'},
#  {'enName': 'AB Aviation',
#   'koName': 'AB 항공',
#   'IATACode': 'Y6',
#   'ICAOCode': '',
#   'status': 'Active'},
#  {'enName': 'Ababeel Aviation',
#   'koName': '아바빌항공',
#   'IATACode': '',
#   'ICAOCode': 'BBE',
#   'status': 'Active'},
#  {'enName': 'Abaete Linhas Aereas',
#   'koName': '아바에테 리나스 아에레스',
#   'IATACode': '',
#   'ICAOCode': 'ABJ',
#   'status': 'Active'},
#  {'enName': 'Aban Air',
#   'koName': '아반 에어',
#   'IATACode': 'K5',
#   'ICAOCode': 'ABE',
#   'status': 'Grounded'},
#  {'enName': 'Abas',
#   'koName': '아바스',
#   'IATACode': '',
#   'ICAOCode': 'MRP',
#   'status': 'Grounded'},
#  {'enName': 'Abc Aerolineas (Interjet)',
#   'koName': 'Abc 아에로리나스',
#   'IATACode': '4O',
#   'ICAOCode': '',
#   'status': 'Active'},
#  {'enName': 'Abc Air Hungary Ltd',
#   'koName': 'ABC 에어헝가리',
#   'IATACode': '',
#   'ICAOCode': 'AHU',
#   'status': 'Grounded'},
#  {'enName': 'ABC Bedarfsflug Gmbh',
#   'koName': 'ABC 베다피쉬플러그',
#   'IATACode': '',
#   'ICAOCode': 'FTY',
#   'status': 'Grounded'},
#  {'enName': 'Abelag Aviation',
#   'koName': '아발렉 에비에이션',
#   'IATACode': 'W9',
#   'ICAOCode': 'AAB',
#   'status': 'Grounded'},
#  {'enName': 'Aberdair Aviation Limited',
#   'koName': '아베르데어 에비에이션',
#   'IATACode': '',
#   'ICAOCode': 'BDV',
#   'status': 'Active'},
#  {'enName': 'Abidjan Air Cargo',
#   'koName': '아비장에어카고',
#   'IATACode': '',
#   'ICAOCode': 'ADJ',
#   'status': 'Grounded'},
#  {'enName': 'Aboitiz Air Transport Corporation',
#   'koName': '아보이티즈항공운송주식회사',
#   'IATACode': '',
#   'ICAOCode': 'BOI',
#   'status': 'Grounded'},
#  {'enName': 'Aboriginal Air Services',
#   'koName': '애브오리지널에어서비스',
#   'IATACode': 'I8',
#   'ICAOCode': '',
#   'status': 'Active'},
#  {'enName': 'Abs Jets',
#   'koName': 'Abs 제트',
#   'IATACode': '',
#   'ICAOCode': 'ABP',
#   'status': 'Active'},
#  {'enName': 'Absolute Flight Services (Pty) Ltd',
#   'koName': '앱설루트 플라이트 서비스',
#   'IATACode': '',
#   'ICAOCode': 'COI',
#   'status': 'Grounded'},
#  {'enName': 'Abu Dhabi Aviation',
#   'koName': '아부다비항공',
#   'IATACode': 'MO',
#   'ICAOCode': 'AXU',
#   'status': 'Grounded'},
#  {'enName': 'ABX Air',
#   'koName': 'ABX 에어',
#   'IATACode': 'GB',
#   'ICAOCode': 'ABX',
#   'status': 'Active'},
#  {'enName': 'ACA-Ancargo Air Sociedade de Transporte de Carga Lda',
#   'koName': '앙카고화물',
#   'IATACode': '',
#   'ICAOCode': 'NCL',
#   'status': 'Grounded'},
#  {'enName': 'Academy Airlines',
#   'koName': '아카데미 에어라인',
#   'IATACode': '',
#   'ICAOCode': 'ACD',
#   'status': 'Grounded'},
#  {'enName': 'Accessair',
#   'koName': '어세스에어',
#   'IATACode': '',
#   'ICAOCode': 'CYD',
#   'status': 'Grounded'},
#  {'enName': 'Ace Air',
#   'koName': '에이스 항공',
#   'IATACode': '',
#   'ICAOCode': 'ATZ',
#   'status': 'Grounded'},
#  {'enName': 'Acef - Transportes Aereos E Cargas, Lda.',
#   'koName': 'Acef - 항공화물운송',
#   'IATACode': '',
#   'ICAOCode': 'CFM',
#   'status': 'Grounded'},
#  {'enName': 'ACG Air Cargo Germany GmbH',
#   'koName': 'ACG 독일에어카고',
#   'IATACode': '6U',
#   'ICAOCode': 'ACX',
#   'status': 'Grounded'},
#  {'enName': 'Acm Air Charter Gmbh',
#   'koName': 'Acm 에어챠터',
#   'IATACode': '',
#   'ICAOCode': 'BVR',
#   'status': 'Grounded'},
#  {'enName': 'Acm Aviation',
#   'koName': 'Acm 에비에이션',
#   'IATACode': '',
#   'ICAOCode': 'BJT',
#   'status': 'Grounded'},
#  {'enName': 'Act International Airlines DBA Texas Airways',
#   'koName': '액트 인터내셔널 에어라인 - 텍사스 에어웨이',
#   'IATACode': '',
#   'ICAOCode': 'CWT',
#   'status': 'Grounded'},
#  {'enName': 'Action Air',
#   'koName': '악티온 에어',
#   'IATACode': '',
#   'ICAOCode': 'ORS',
#   'status': 'Grounded'},
#  {'enName': 'Action Airlines',
#   'koName': '액션 에어라인',
#   'IATACode': '',
#   'ICAOCode': 'AXQ',
#   'status': 'Grounded'},
#  {'enName': 'Active Aero Charter Inc',
#   'koName': '액티브에어로챠터',
#   'IATACode': '',
#   'ICAOCode': 'AVR',
#   'status': 'Grounded'},
#  {'enName': 'Acvila Air-Romanian Carrier',
#   'koName': '악빌랴 에어-루마니아항공사',
#   'IATACode': '',
#   'ICAOCode': 'RRM',
#   'status': 'Grounded'},
#  {'enName': 'Ad Aviation Limited',
#   'koName': 'AD 항공',
#   'IATACode': 'V6',
#   'ICAOCode': 'VUE',
#   'status': 'Grounded'},
#  {'enName': 'Ada Air',
#   'koName': '아다 에어',
#   'IATACode': 'ZY',
#   'ICAOCode': 'ADE',
#   'status': 'Grounded'},
#  {'enName': 'Addis Air Cargo Services P.L.C.',
#   'koName': '아디스항공화물서비스',
#   'IATACode': '',
#   'ICAOCode': 'DSC',
#   'status': 'Grounded'},
#  {'enName': 'Addis Airlines Plc',
#   'koName': '애디스 에어라인',
#   'IATACode': '',
#   'ICAOCode': 'DDS',
#   'status': 'Grounded'},
#  {'enName': 'Adefa, S.A.',
#   'koName': 'Adefa',
#   'IATACode': '',
#   'ICAOCode': 'ADF',
#   'status': 'Grounded'},
#  {'enName': 'Adi Shuttle Group, Llc ',
#   'koName': 'ADI 셔틀 그룹',
#   'IATACode': '',
#   'ICAOCode': 'TEC',
#   'status': 'Grounded'},
#  {'enName': 'Adler Aviation Ltd',
#   'koName': '앨더 에비에이션',
#   'IATACode': '',
#   'ICAOCode': 'SWH',
#   'status': 'Grounded'},
#  {'enName': 'Administracion De Aeropuertos Y Servicios Auxiliares A La',
#   'koName': '어드미니스트레이션 드 에어로부에르토스',
#   'IATACode': '',
#   'ICAOCode': 'XXV',
#   'status': 'Grounded'},
#  {'enName': 'Adria Airways',
#   'koName': '아드리아 항공사',
#   'IATACode': 'JP',
#   'ICAOCode': 'ADR',
#   'status': 'Grounded'},
#  {'enName': 'Adria Airways Switzerland',
#   'koName': '다윈항공',
#   'IATACode': 'F7',
#   'ICAOCode': '',
#   'status': 'Grounded'},
#  {'enName': 'Advance Aviation Services',
#   'koName': '어드밴스 항공서비스',
#   'IATACode': '',
#   'ICAOCode': 'XTJ',
#   'status': 'Grounded'},
#  {'enName': 'Advanced Flight Training Ltd',
#   'koName': '어드벤스 플라이트 트레이닝',
#   'IATACode': '',
#   'ICAOCode': 'ADV',
#   'status': 'Grounded'},
#  {'enName': 'Adventia',
#   'koName': '어드벤티아',
#   'IATACode': '',
#   'ICAOCode': 'DVN',
#   'status': 'Grounded'},
#  {'enName': 'Adygeya Airlines',
#   'koName': '아디게야 에어라인',
#   'IATACode': '',
#   'ICAOCode': 'RDD',
#   'status': 'Grounded'},
#  {'enName': 'AeBal (Aerolineas de Baleares )',
#   'koName': '에어발',
#   'IATACode': 'DF',
#   'ICAOCode': '',
#   'status': 'Grounded'},
#  {'enName': 'Aeg Aviation Services ',
#   'koName': 'AEG 에비에이션 서비스',
#   'IATACode': '',
#   'ICAOCode': 'EBS',
#   'status': 'Grounded'},
#  {'enName': 'Aegean Airlines',
#   'koName': '에게안항공',
#   'IATACode': 'A3',
#   'ICAOCode': 'AEE',
#   'status': 'Active'},
#  {'enName': 'Aeolus Air',
#   'koName': '에올러스 항공',
#   'IATACode': '',
#   'ICAOCode': 'AAZ',
#   'status': 'Active'},
#  {'enName': 'Aer Caribe',
#   'koName': '에어카리브',
#   'IATACode': '',
#   'ICAOCode': 'ACL',
#   'status': 'Grounded'},
#  {'enName': 'Aer Caribe Peru',
#   'koName': '페루에어카리브',
#   'IATACode': '',
#   'ICAOCode': 'CPR',
#   'status': 'Active'},
#  {'enName': 'Aer Lingus',
#   'koName': '에어링거스',
#   'IATACode': 'EI',
#   'ICAOCode': 'EIN',
#   'status': 'Active'},
#  {'enName': 'Aeralp',
#   'koName': '아렐프',
#   'IATACode': '',
#   'ICAOCode': 'ALS',
#   'status': 'Grounded'},
#  {'enName': 'AerCaribe',
#   'koName': '에어카리베',
#   'IATACode': 'JK',
#   'ICAOCode': 'ACL',
#   'status': 'Active'},
#  {'enName': 'Aerea Flying Training Organization , S.A.',
#   'koName': '아에레 플라잉 트레이닝 오가나이제이션',
#   'IATACode': '',
#   'ICAOCode': 'ADG',
#   'status': 'Grounded'},
#  {'enName': 'Aerea Transportes Aereos Del Pacifico',
#   'koName': '델 퍼시픽 에어트랜스포츠',
#   'IATACode': '',
#   'ICAOCode': 'TAF',
#   'status': 'Grounded'},
#  {'enName': 'Aereo Cabo',
#   'koName': '아에로 카보',
#   'IATACode': '',
#   'ICAOCode': 'CBV',
#   'status': 'Grounded'},
#  {'enName': 'Aereo Calafia',
#   'koName': '칼라피아항공',
#   'IATACode': 'A7',
#   'ICAOCode': 'CFV',
#   'status': 'Active'},
#  {'enName': 'Aereo Ruta Maya',
#   'koName': '에어로 루타 마야',
#   'IATACode': '',
#   'ICAOCode': 'MMG',
#   'status': 'Grounded'},
#  {'enName': 'Aereo Taxi Autlan',
#   'koName': '아우틀란 에어택시',
#   'IATACode': '',
#   'ICAOCode': 'TLD',
#   'status': 'Grounded'},
#  {'enName': 'Aereo Taxi Paraza',
#   'koName': '아에로 택시 파라자',
#   'IATACode': '',
#   'ICAOCode': 'PZA',
#   'status': 'Grounded'},
#  {'enName': 'Aereo Transportes Los Angeles De America',
#   'koName': '로스엔젤레스 아메리카항공운송',
#   'IATACode': '',
#   'ICAOCode': 'AGI',
#   'status': 'Grounded'},
#  {'enName': 'Aereo Wwg.',
#   'koName': '에어로 WWG',
#   'IATACode': '',
#   'ICAOCode': 'WWG',
#   'status': 'Grounded'},
#  {'enName': 'Aereos Pacifico',
#   'koName': '아에로 퍼시피코',
#   'IATACode': '',
#   'ICAOCode': 'TFO',
#   'status': 'Grounded'},
#  {'enName': 'Aereosaba',
#   'koName': '아에로사바',
#   'IATACode': '',
#   'ICAOCode': 'ESB',
#   'status': 'Grounded'},
#  {'enName': 'Aereotaxis',
#   'koName': '아에로택시스',
#   'IATACode': '',
#   'ICAOCode': 'TXI',
#   'status': 'Grounded'},
#  {'enName': 'Aereotuy',
#   'koName': '에레오투이',
#   'IATACode': 'L4',
#   'ICAOCode': '',
#   'status': 'Active'},
#  {'enName': 'AERFI Group plc',
#   'koName': 'AERFI 그룹 plc',
#   'IATACode': '',
#   'ICAOCode': 'AGP',
#   'status': 'Grounded'},
#  {'enName': 'Aerial Surveys (1980) Ltd',
#   'koName': '에어리얼 서베이 1980',
#   'IATACode': '',
#   'ICAOCode': 'SUY',
#   'status': 'Grounded'},
#  {'enName': 'Aerial Transit Company',
#   'koName': '에어리얼 트린짓',
#   'IATACode': '',
#   'ICAOCode': 'AEZ',
#   'status': 'Grounded'},
#  {'enName': 'Aeriantur-M',
#   'koName': '아리안트루-M',
#   'IATACode': '',
#   'ICAOCode': 'MBV',
#   'status': 'Grounded'},
#  {'enName': 'Aeris Gestion S.L.',
#   'koName': '아에리스 제스티옹',
#   'IATACode': '',
#   'ICAOCode': 'RIS',
#   'status': 'Grounded'},
#  {'enName': 'Aermarche',
#   'koName': '아에르마체',
#   'IATACode': '',
#   'ICAOCode': 'MMC',
#   'status': 'Grounded'},
#  {'enName': 'Aero (Nigeria)',
#   'koName': '에어라 나이지리아',
#   'IATACode': 'NG',
#   'ICAOCode': 'NIG',
#   'status': 'Active'},
#  {'enName': 'Aero 1 Prop-Jet',
#   'koName': '에어로 1 프롭-제트',
#   'IATACode': '',
#   'ICAOCode': 'SSM',
#   'status': 'Grounded'},
#  {'enName': 'Aero Africa',
#   'koName': '에어로아프리카',
#   'IATACode': '',
#   'ICAOCode': 'RFC',
#   'status': 'Grounded'},
#  {'enName': 'Aero Air, Llc',
#   'koName': '에어로 에어',
#   'IATACode': '',
#   'ICAOCode': 'WIL',
#   'status': 'Grounded'},
#  {'enName': '135 Airways',
#   'koName': '135 에어웨이',
#   'IATACode': '',
#   'ICAOCode': 'GNL',
#   'status': 'Grounded'},
#  {'enName': '1time',
#   'koName': '1타임항공',
#   'IATACode': '1T',
#   'ICAOCode': 'RNX',
#   'status': 'Grounded'},
#  {'enName': '2 Sqn, No 1 Elementary Flying Training School',
#   'koName': 'No 기초비행훈련스쿨 2편대',
#   'IATACode': '',
#   'ICAOCode': 'WYT',
#   'status': 'Grounded'},
#  {'enName': '21 Air',
#   'koName': '21 에어',
#   'IATACode': '2I',
#   'ICAOCode': 'CSB',
#   'status': 'Active'},
#  {'enName': '213 Flight Unit',
#   'koName': '213 비행대대',
#   'IATACode': '',
#   'ICAOCode': 'TFU',
#   'status': 'Grounded'},
#  {'enName': '223 Flight Unit, State Airline',
#   'koName': '223 비행대대, 스테이트 에어라인',
#   'IATACode': '',
#   'ICAOCode': 'CHD',
#   'status': 'Grounded'},
#  {'enName': '224th Flight Unit',
#   'koName': '224 비행대대',
#   'IATACode': '',
#   'ICAOCode': 'TTF',
#   'status': 'Grounded'},
#  {'enName': '247 Jet Ltd',
#   'koName': '247 제트',
#   'IATACode': '',
#   'ICAOCode': 'TWF',
#   'status': 'Grounded'},
#  {'enName': '32 (Tr) Squadron, Raf Northolt',
#   'koName': '영국공군 노솔트 32대대',
#   'IATACode': '',
#   'ICAOCode': 'NOH',
#   'status': 'Grounded'},
#  {'enName': '3D Aviation',
#   'koName': '3D 에비에이션',
#   'IATACode': '',
#   'ICAOCode': 'SEC',
#   'status': 'Grounded'},
#  {'enName': '3Grcomm Ltd (T/A Crest Aviation)',
#   'koName': '3G 알콤 - 크레스트 항공',
#   'IATACode': '',
#   'ICAOCode': 'CAN',
#   'status': 'Grounded'},
#  {'enName': '40 Mile Air',
#   'koName': '40마일에어',
#   'IATACode': 'Q5',
#   'ICAOCode': 'MLA',
#   'status': 'Active'},
#  {'enName': '43 Air School',
#   'koName': '43 비행스쿨',
#   'IATACode': '',
#   'ICAOCode': 'PIU',
#   'status': 'Grounded'},
#  {'enName': '4D Air',
#   'koName': '4D 에어',
#   'IATACode': '',
#   'ICAOCode': 'QRT',
#   'status': 'Grounded'},
#  {'enName': '540 Ghana Ltd.',
#   'koName': '540 가나',
#   'IATACode': '5G',
#   'ICAOCode': '',
#   'status': 'Active'},
#  {'enName': '611897 Alberta Ltd',
#   'koName': '611897 앨버타',
#   'IATACode': '',
#   'ICAOCode': 'THD',
#   'status': 'Active'},
#  {'enName': '748 Air Services',
#   'koName': '748 항공서비스',
#   'IATACode': '',
#   'ICAOCode': 'IHO',
#   'status': 'Active'},
#  {'enName': '84 Sqn Raf Akrotiri',
#   'koName': '아크로티리 공군 84연대',
#   'IATACode': '',
#   'ICAOCode': 'AKG',
#   'status': 'Grounded'},
#  {'enName': '9 Air',
#   'koName': '9 에어',
#   'IATACode': 'AQ',
#   'ICAOCode': 'JYH',
#   'status': 'Active'},
#  {'enName': '9G Rail Limited',
#   'koName': '9G 레일',
#   'IATACode': '9G',
#   'ICAOCode': '',
#   'status': 'Grounded'},
#  {'enName': 'AA 767, LLC',
#   'koName': 'aa 767',
#   'IATACode': '7Q',
#   'ICAOCode': '',
#   'status': 'Active'},
#  {'enName': 'AAA - Air Alps Aviation Ges.M.B.H.',
#   'koName': 'AAA - 에어알프스 항공',
#   'IATACode': 'A6',
#   'ICAOCode': 'LPV',
#   'status': 'Grounded'},
#  {'enName': 'AB Aviation',
#   'koName': 'AB 항공',
#   'IATACode': 'Y6',
#   'ICAOCode': 'CYK',
#   'status': 'Grounded'},
#  {'enName': 'AB Aviation',
#   'koName': 'AB 항공',
#   'IATACode': 'Y6',
#   'ICAOCode': '',
#   'status': 'Active'},
#  {'enName': 'Ababeel Aviation',
#   'koName': '아바빌항공',
#   'IATACode': '',
#   'ICAOCode': 'BBE',
#   'status': 'Active'},
#  {'enName': 'Abaete Linhas Aereas',
#   'koName': '아바에테 리나스 아에레스',
#   'IATACode': '',
#   'ICAOCode': 'ABJ',
#   'status': 'Active'},
#  {'enName': 'Aban Air',
#   'koName': '아반 에어',
#   'IATACode': 'K5',
#   'ICAOCode': 'ABE',
#   'status': 'Grounded'},
#  {'enName': 'Abas',
#   'koName': '아바스',
#   'IATACode': '',
#   'ICAOCode': 'MRP',
#   'status': 'Grounded'},
#  {'enName': 'Abc Aerolineas (Interjet)',
#   'koName': 'Abc 아에로리나스',
#   'IATACode': '4O',
#   'ICAOCode': '',
#   'status': 'Active'},
#  {'enName': 'Abc Air Hungary Ltd',
#   'koName': 'ABC 에어헝가리',
#   'IATACode': '',
#   'ICAOCode': 'AHU',
#   'status': 'Grounded'},
#  {'enName': 'ABC Bedarfsflug Gmbh',
#   'koName': 'ABC 베다피쉬플러그',
#   'IATACode': '',
#   'ICAOCode': 'FTY',
#   'status': 'Grounded'},
#  {'enName': 'Abelag Aviation',
#   'koName': '아발렉 에비에이션',
#   'IATACode': 'W9',
#   'ICAOCode': 'AAB',
#   'status': 'Grounded'},
#  {'enName': 'Aberdair Aviation Limited',
#   'koName': '아베르데어 에비에이션',
#   'IATACode': '',
#   'ICAOCode': 'BDV',
#   'status': 'Active'},
#  {'enName': 'Abidjan Air Cargo',
#   'koName': '아비장에어카고',
#   'IATACode': '',
#   'ICAOCode': 'ADJ',
#   'status': 'Grounded'},
#  {'enName': 'Aboitiz Air Transport Corporation',
#   'koName': '아보이티즈항공운송주식회사',
#   'IATACode': '',
#   'ICAOCode': 'BOI',
#   'status': 'Grounded'},
#  {'enName': 'Aboriginal Air Services',
#   'koName': '애브오리지널에어서비스',
#   'IATACode': 'I8',
#   'ICAOCode': '',
#   'status': 'Active'},
#  {'enName': 'Abs Jets',
#   'koName': 'Abs 제트',
#   'IATACode': '',
#   'ICAOCode': 'ABP',
#   'status': 'Active'},
#  {'enName': 'Absolute Flight Services (Pty) Ltd',
#   'koName': '앱설루트 플라이트 서비스',
#   'IATACode': '',
#   'ICAOCode': 'COI',
#   'status': 'Grounded'},
#  {'enName': 'Abu Dhabi Aviation',
#   'koName': '아부다비항공',
#   'IATACode': 'MO',
#   'ICAOCode': 'AXU',
#   'status': 'Grounded'},
#  {'enName': 'ABX Air',
#   'koName': 'ABX 에어',
#   'IATACode': 'GB',
#   'ICAOCode': 'ABX',
#   'status': 'Active'},
#  {'enName': 'ACA-Ancargo Air Sociedade de Transporte de Carga Lda',
#   'koName': '앙카고화물',
#   'IATACode': '',
#   'ICAOCode': 'NCL',
#   'status': 'Grounded'},
#  {'enName': 'Academy Airlines',
#   'koName': '아카데미 에어라인',
#   'IATACode': '',
#   'ICAOCode': 'ACD',
#   'status': 'Grounded'},
#  {'enName': 'Accessair',
#   'koName': '어세스에어',
#   'IATACode': '',
#   'ICAOCode': 'CYD',
#   'status': 'Grounded'},
#  {'enName': 'Ace Air',
#   'koName': '에이스 항공',
#   'IATACode': '',
#   'ICAOCode': 'ATZ',
#   'status': 'Grounded'},
#  {'enName': 'Acef - Transportes Aereos E Cargas, Lda.',
#   'koName': 'Acef - 항공화물운송',
#   'IATACode': '',
#   'ICAOCode': 'CFM',
#   'status': 'Grounded'},
#  {'enName': 'ACG Air Cargo Germany GmbH',
#   'koName': 'ACG 독일에어카고',
#   'IATACode': '6U',
#   'ICAOCode': 'ACX',
#   'status': 'Grounded'},
#  {'enName': 'Acm Air Charter Gmbh',
#   'koName': 'Acm 에어챠터',
#   'IATACode': '',
#   'ICAOCode': 'BVR',
#   'status': 'Grounded'},
#  {'enName': 'Acm Aviation',
#   'koName': 'Acm 에비에이션',
#   'IATACode': '',
#   'ICAOCode': 'BJT',
#   'status': 'Grounded'},
#  {'enName': 'Act International Airlines DBA Texas Airways',
#   'koName': '액트 인터내셔널 에어라인 - 텍사스 에어웨이',
#   'IATACode': '',
#   'ICAOCode': 'CWT',
#   'status': 'Grounded'},
#  {'enName': 'Action Air',
#   'koName': '악티온 에어',
#   'IATACode': '',
#   'ICAOCode': 'ORS',
#   'status': 'Grounded'},
#  {'enName': 'Action Airlines',
#   'koName': '액션 에어라인',
#   'IATACode': '',
#   'ICAOCode': 'AXQ',
#   'status': 'Grounded'},
#  {'enName': 'Active Aero Charter Inc',
#   'koName': '액티브에어로챠터',
#   'IATACode': '',
#   'ICAOCode': 'AVR',
#   'status': 'Grounded'},
#  {'enName': 'Acvila Air-Romanian Carrier',
#   'koName': '악빌랴 에어-루마니아항공사',
#   'IATACode': '',
#   'ICAOCode': 'RRM',
#   'status': 'Grounded'},
#  {'enName': 'Ad Aviation Limited',
#   'koName': 'AD 항공',
#   'IATACode': 'V6',
#   'ICAOCode': 'VUE',
#   'status': 'Grounded'},
#  {'enName': 'Ada Air',
#   'koName': '아다 에어',
#   'IATACode': 'ZY',
#   'ICAOCode': 'ADE',
#   'status': 'Grounded'},
#  {'enName': 'Addis Air Cargo Services P.L.C.',
#   'koName': '아디스항공화물서비스',
#   'IATACode': '',
#   'ICAOCode': 'DSC',
#   'status': 'Grounded'},
#  {'enName': 'Addis Airlines Plc',
#   'koName': '애디스 에어라인',
#   'IATACode': '',
#   'ICAOCode': 'DDS',
#   'status': 'Grounded'},
#  {'enName': 'Adefa, S.A.',
#   'koName': 'Adefa',
#   'IATACode': '',
#   'ICAOCode': 'ADF',
#   'status': 'Grounded'},
#  {'enName': 'Adi Shuttle Group, Llc ',
#   'koName': 'ADI 셔틀 그룹',
#   'IATACode': '',
#   'ICAOCode': 'TEC',
#   'status': 'Grounded'},
#  {'enName': 'Adler Aviation Ltd',
#   'koName': '앨더 에비에이션',
#   'IATACode': '',
#   'ICAOCode': 'SWH',
#   'status': 'Grounded'},
#  {'enName': 'Administracion De Aeropuertos Y Servicios Auxiliares A La',
#   'koName': '어드미니스트레이션 드 에어로부에르토스',
#   'IATACode': '',
#   'ICAOCode': 'XXV',
#   'status': 'Grounded'},
#  {'enName': 'Adria Airways',
#   'koName': '아드리아 항공사',
#   'IATACode': 'JP',
#   'ICAOCode': 'ADR',
#   'status': 'Grounded'},
#  {'enName': 'Adria Airways Switzerland',
#   'koName': '다윈항공',
#   'IATACode': 'F7',
#   'ICAOCode': '',
#   'status': 'Grounded'},
#  {'enName': 'Advance Aviation Services',
#   'koName': '어드밴스 항공서비스',
#   'IATACode': '',
#   'ICAOCode': 'XTJ',
#   'status': 'Grounded'},
#  {'enName': 'Advanced Flight Training Ltd',
#   'koName': '어드벤스 플라이트 트레이닝',
#   'IATACode': '',
#   'ICAOCode': 'ADV',
#   'status': 'Grounded'},
#  {'enName': 'Adventia',
#   'koName': '어드벤티아',
#   'IATACode': '',
#   'ICAOCode': 'DVN',
#   'status': 'Grounded'},
#  {'enName': 'Adygeya Airlines',
#   'koName': '아디게야 에어라인',
#   'IATACode': '',
#   'ICAOCode': 'RDD',
#   'status': 'Grounded'},
#  {'enName': 'AeBal (Aerolineas de Baleares )',
#   'koName': '에어발',
#   'IATACode': 'DF',
#   'ICAOCode': '',
#   'status': 'Grounded'},
#  {'enName': 'Aeg Aviation Services ',
#   'koName': 'AEG 에비에이션 서비스',
#   'IATACode': '',
#   'ICAOCode': 'EBS',
#   'status': 'Grounded'},
#  {'enName': 'Aegean Airlines',
#   'koName': '에게안항공',
#   'IATACode': 'A3',
#   'ICAOCode': 'AEE',
#   'status': 'Active'},
#  {'enName': 'Aeolus Air',
#   'koName': '에올러스 항공',
#   'IATACode': '',
#   'ICAOCode': 'AAZ',
#   'status': 'Active'},
#  {'enName': 'Aer Caribe',
#   'koName': '에어카리브',
#   'IATACode': '',
#   'ICAOCode': 'ACL',
#   'status': 'Grounded'},
#  {'enName': 'Aer Caribe Peru',
#   'koName': '페루에어카리브',
#   'IATACode': '',
#   'ICAOCode': 'CPR',
#   'status': 'Active'},
#  {'enName': 'Aer Lingus',
#   'koName': '에어링거스',
#   'IATACode': 'EI',
#   'ICAOCode': 'EIN',
#   'status': 'Active'},
#  {'enName': 'Aeralp',
#   'koName': '아렐프',
#   'IATACode': '',
#   'ICAOCode': 'ALS',
#   'status': 'Grounded'},
#  {'enName': 'AerCaribe',
#   'koName': '에어카리베',
#   'IATACode': 'JK',
#   'ICAOCode': 'ACL',
#   'status': 'Active'},
#  {'enName': 'Aerea Flying Training Organization , S.A.',
#   'koName': '아에레 플라잉 트레이닝 오가나이제이션',
#   'IATACode': '',
#   'ICAOCode': 'ADG',
#   'status': 'Grounded'},
#  {'enName': 'Aerea Transportes Aereos Del Pacifico',
#   'koName': '델 퍼시픽 에어트랜스포츠',
#   'IATACode': '',
#   'ICAOCode': 'TAF',
#   'status': 'Grounded'},
#  {'enName': 'Aereo Cabo',
#   'koName': '아에로 카보',
#   'IATACode': '',
#   'ICAOCode': 'CBV',
#   'status': 'Grounded'},
#  {'enName': 'Aereo Calafia',
#   'koName': '칼라피아항공',
#   'IATACode': 'A7',
#   'ICAOCode': 'CFV',
#   'status': 'Active'},
#  {'enName': 'Aereo Ruta Maya',
#   'koName': '에어로 루타 마야',
#   'IATACode': '',
#   'ICAOCode': 'MMG',
#   'status': 'Grounded'},
#  {'enName': 'Aereo Taxi Autlan',
#   'koName': '아우틀란 에어택시',
#   'IATACode': '',
#   'ICAOCode': 'TLD',
#   'status': 'Grounded'},
#  {'enName': 'Aereo Taxi Paraza',
#   'koName': '아에로 택시 파라자',
#   'IATACode': '',
#   'ICAOCode': 'PZA',
#   'status': 'Grounded'},
#  {'enName': 'Aereo Transportes Los Angeles De America',
#   'koName': '로스엔젤레스 아메리카항공운송',
#   'IATACode': '',
#   'ICAOCode': 'AGI',
#   'status': 'Grounded'},
#  {'enName': 'Aereo Wwg.',
#   'koName': '에어로 WWG',
#   'IATACode': '',
#   'ICAOCode': 'WWG',
#   'status': 'Grounded'},
#  {'enName': 'Aereos Pacifico',
#   'koName': '아에로 퍼시피코',
#   'IATACode': '',
#   'ICAOCode': 'TFO',
#   'status': 'Grounded'},
#  {'enName': 'Aereosaba',
#   'koName': '아에로사바',
#   'IATACode': '',
#   'ICAOCode': 'ESB',
#   'status': 'Grounded'},
#  {'enName': 'Aereotaxis',
#   'koName': '아에로택시스',
#   'IATACode': '',
#   'ICAOCode': 'TXI',
#   'status': 'Grounded'},
#  {'enName': 'Aereotuy',
#   'koName': '에레오투이',
#   'IATACode': 'L4',
#   'ICAOCode': '',
#   'status': 'Active'},
#  {'enName': 'AERFI Group plc',
#   'koName': 'AERFI 그룹 plc',
#   'IATACode': '',
#   'ICAOCode': 'AGP',
#   'status': 'Grounded'},
#  {'enName': 'Aerial Surveys (1980) Ltd',
#   'koName': '에어리얼 서베이 1980',
#   'IATACode': '',
#   'ICAOCode': 'SUY',
#   'status': 'Grounded'},
#  {'enName': 'Aerial Transit Company',
#   'koName': '에어리얼 트린짓',
#   'IATACode': '',
#   'ICAOCode': 'AEZ',
#   'status': 'Grounded'},
#  {'enName': 'Aeriantur-M',
#   'koName': '아리안트루-M',
#   'IATACode': '',
#   'ICAOCode': 'MBV',
#   'status': 'Grounded'},
#  {'enName': 'Aeris Gestion S.L.',
#   'koName': '아에리스 제스티옹',
#   'IATACode': '',
#   'ICAOCode': 'RIS',
#   'status': 'Grounded'},
#  {'enName': 'Aermarche',
#   'koName': '아에르마체',
#   'IATACode': '',
#   'ICAOCode': 'MMC',
#   'status': 'Grounded'},
#  {'enName': 'Aero (Nigeria)',
#   'koName': '에어라 나이지리아',
#   'IATACode': 'NG',
#   'ICAOCode': 'NIG',
#   'status': 'Active'},
#  {'enName': 'Aero 1 Prop-Jet',
#   'koName': '에어로 1 프롭-제트',
#   'IATACode': '',
#   'ICAOCode': 'SSM',
#   'status': 'Grounded'},
#  {'enName': 'Aero Africa',
#   'koName': '에어로아프리카',
#   'IATACode': '',
#   'ICAOCode': 'RFC',
#   'status': 'Grounded'},
#  {'enName': 'Aero Air, Llc',
#   'koName': '에어로 에어',
#   'IATACode': '',
#   'ICAOCode': 'WIL',
#   'status': 'Grounded'}]

# %%
#update

with open('../data/airline_info.csv', encoding='cp949') as f:
    csv_info = csv.reader(f, delimiter=',')
    
    result = []
    
    next(csv_info, None) # to skip csv header 
    #항공사명 한글항공사명 IATA코드 ICAO코드 항공사상태 사업모델 국가 지역

    for row in csv_info:
        to_json = {"$set":{
            'businessModel': row[5],
            'enCountryName': row[6],
            'enCityName': row[7],
        }}
        #query를 기준으로 찾아 새로운 데이터 추가
        query = {'ICAOCode':row[3]}
        new_value = to_json
        try:
            airline_collection.update_one(query, new_value)
        except:
            print(f'not found {row[3]}')
            pass
# Out:
# <pymongo.results.UpdateResult object at 0x04A17728>
# <pymongo.results.UpdateResult object at 0x04BF91E8>
# <pymongo.results.UpdateResult object at 0x04A17328>
# <pymongo.results.UpdateResult object at 0x04A17388>
# <pymongo.results.UpdateResult object at 0x06EC3BE8>
# <pymongo.results.UpdateResult object at 0x04A17028>
# <pymongo.results.UpdateResult object at 0x06EE2168>
# <pymongo.results.UpdateResult object at 0x04A171C8>
# <pymongo.results.UpdateResult object at 0x04A173A8>
# <pymongo.results.UpdateResult object at 0x06EE26C8>
# <pymongo.results.UpdateResult object at 0x04A17408>
# <pymongo.results.UpdateResult object at 0x04BF91E8>
# <pymongo.results.UpdateResult object at 0x04A173E8>
# <pymongo.results.UpdateResult object at 0x06EE2168>
# <pymongo.results.UpdateResult object at 0x04A173E8>
# <pymongo.results.UpdateResult object at 0x06EE2168>
# <pymongo.results.UpdateResult object at 0x04A172E8>
# <pymongo.results.UpdateResult object at 0x04BF91E8>
# <pymongo.results.UpdateResult object at 0x06EC3BE8>
# <pymongo.results.UpdateResult object at 0x04A17748>
# <pymongo.results.UpdateResult object at 0x06EE26C8>
# <pymongo.results.UpdateResult object at 0x06EE2168>
# <pymongo.results.UpdateResult object at 0x04A17748>
# <pymongo.results.UpdateResult object at 0x06EC8028>
# <pymongo.results.UpdateResult object at 0x04A17208>
# <pymongo.results.UpdateResult object at 0x04A172A8>
# <pymongo.results.UpdateResult object at 0x04BF91E8>
# <pymongo.results.UpdateResult object at 0x04A17208>
# <pymongo.results.UpdateResult object at 0x06EE2168>
# <pymongo.results.UpdateResult object at 0x06EC3BE8>
# <pymongo.results.UpdateResult object at 0x04A17388>
# <pymongo.results.UpdateResult object at 0x04A17308>
# <pymongo.results.UpdateResult object at 0x04A17388>
# <pymongo.results.UpdateResult object at 0x04BF91E8>
# <pymongo.results.UpdateResult object at 0x04A17348>
# <pymongo.results.UpdateResult object at 0x04A17308>
# <pymongo.results.UpdateResult object at 0x06EC3BE8>
# <pymongo.results.UpdateResult object at 0x04A173E8>
# <pymongo.results.UpdateResult object at 0x04A17348>
# <pymongo.results.UpdateResult object at 0x06EE26C8>
# <pymongo.results.UpdateResult object at 0x04BF91E8>
# <pymongo.results.UpdateResult object at 0x04A17348>
# <pymongo.results.UpdateResult object at 0x04A173C8>
# <pymongo.results.UpdateResult object at 0x04A17348>
# <pymongo.results.UpdateResult object at 0x06EE2168>
# <pymongo.results.UpdateResult object at 0x06EE26C8>
# <pymongo.results.UpdateResult object at 0x04A17348>
# <pymongo.results.UpdateResult object at 0x06EE26C8>
# <pymongo.results.UpdateResult object at 0x04A17328>
# <pymongo.results.UpdateResult object at 0x04A17148>
# <pymongo.results.UpdateResult object at 0x04BF91E8>
# <pymongo.results.UpdateResult object at 0x06EE26C8>
# <pymongo.results.UpdateResult object at 0x04A173C8>
# <pymongo.results.UpdateResult object at 0x06EC8028>
# <pymongo.results.UpdateResult object at 0x06EC8448>
# <pymongo.results.UpdateResult object at 0x06EE2168>
# <pymongo.results.UpdateResult object at 0x06EC8028>
# <pymongo.results.UpdateResult object at 0x06EE2168>
# <pymongo.results.UpdateResult object at 0x06EC3BE8>
# <pymongo.results.UpdateResult object at 0x04BF91E8>
# <pymongo.results.UpdateResult object at 0x06EE26C8>
# <pymongo.results.UpdateResult object at 0x04A175E8>
# <pymongo.results.UpdateResult object at 0x06EC8448>
# <pymongo.results.UpdateResult object at 0x06EC8028>
# <pymongo.results.UpdateResult object at 0x04A17448>
# <pymongo.results.UpdateResult object at 0x06EC3BE8>
# <pymongo.results.UpdateResult object at 0x04A17368>
# <pymongo.results.UpdateResult object at 0x06EE26C8>
# <pymongo.results.UpdateResult object at 0x06EC3BE8>
# <pymongo.results.UpdateResult object at 0x04A174C8>
# <pymongo.results.UpdateResult object at 0x06EE26C8>
# <pymongo.results.UpdateResult object at 0x06EC3BE8>
# <pymongo.results.UpdateResult object at 0x06EC8028>
# <pymongo.results.UpdateResult object at 0x04A17388>
# <pymongo.results.UpdateResult object at 0x06EC3BE8>
# <pymongo.results.UpdateResult object at 0x06EC8448>
# <pymongo.results.UpdateResult object at 0x06EE2168>
# <pymongo.results.UpdateResult object at 0x04A17748>
# <pymongo.results.UpdateResult object at 0x06EE26C8>
# <pymongo.results.UpdateResult object at 0x06EC8028>
# <pymongo.results.UpdateResult object at 0x06EE2168>
# <pymongo.results.UpdateResult object at 0x04A17408>
# <pymongo.results.UpdateResult object at 0x04A175E8>
# <pymongo.results.UpdateResult object at 0x06EE2168>
# <pymongo.results.UpdateResult object at 0x06EC3BE8>
# <pymongo.results.UpdateResult object at 0x04A172A8>
# <pymongo.results.UpdateResult object at 0x06EC8028>
# <pymongo.results.UpdateResult object at 0x04A171C8>
# <pymongo.results.UpdateResult object at 0x04BF91E8>
# <pymongo.results.UpdateResult object at 0x06EC8028>
# <pymongo.results.UpdateResult object at 0x04A17568>
# <pymongo.results.UpdateResult object at 0x04BF91E8>
# <pymongo.results.UpdateResult object at 0x04A175E8>
# <pymongo.results.UpdateResult object at 0x06EE26C8>
# <pymongo.results.UpdateResult object at 0x06EC3BE8>
# <pymongo.results.UpdateResult object at 0x04A17388>
# <pymongo.results.UpdateResult object at 0x06EE26C8>
# <pymongo.results.UpdateResult object at 0x04BF91E8>
# <pymongo.results.UpdateResult object at 0x04A17388>

# %% [markdown]
# ## Sliced
# 원본 `iata~` 파일들을 100개단위로 자른 새로운 파일 생성

# %%
filename = '../data/iata_airline_code.csv'
new_filename = '../data/airline_code.csv'
with open(filename, encoding='cp949') as f:
    lines = f.readlines()[:100]
    with open(new_filename, 'w', encoding='cp949') as g:
        for line in lines:
            g.write(line)

# %%
with open(new_filename, encoding='cp949') as f:
    csv_reader = csv.reader(f, delimiter=',')
    for row in csv_reader:
        print(row)
# Out:
# ['항공사(영문명)', '항공사(한글명)', '항공사코드(IATA)', '항공사코드(ICAO)', '항공사상태']
# ['135 Airways', '135 에어웨이', '', 'GNL', 'Grounded']
# ['1time', '1타임항공', '1T', 'RNX', 'Grounded']
# ['2 Sqn, No 1 Elementary Flying Training School', 'No 기초비행훈련스쿨 2편대', '', 'WYT', 'Grounded']
# ['21 Air', '21 에어', '2I', 'CSB', 'Active']
# ['213 Flight Unit', '213 비행대대', '', 'TFU', 'Grounded']
# ['223 Flight Unit, State Airline', '223 비행대대, 스테이트 에어라인', '', 'CHD', 'Grounded']
# ['224th Flight Unit', '224 비행대대', '', 'TTF', 'Grounded']
# ['247 Jet Ltd', '247 제트', '', 'TWF', 'Grounded']
# ['32 (Tr) Squadron, Raf Northolt', '영국공군 노솔트 32대대', '', 'NOH', 'Grounded']
# ['3D Aviation', '3D 에비에이션', '', 'SEC', 'Grounded']
# ['3Grcomm Ltd (T/A Crest Aviation)', '3G 알콤 - 크레스트 항공', '', 'CAN', 'Grounded']
# ['40 Mile Air', '40마일에어', 'Q5', 'MLA', 'Active']
# ['43 Air School', '43 비행스쿨', '', 'PIU', 'Grounded']
# ['4D Air', '4D 에어', '', 'QRT', 'Grounded']
# ['540 Ghana Ltd.', '540 가나', '5G', '', 'Active']
# ['611897 Alberta Ltd', '611897 앨버타', '', 'THD', 'Active']
# ['748 Air Services', '748 항공서비스', '', 'IHO', 'Active']
# ['84 Sqn Raf Akrotiri', '아크로티리 공군 84연대', '', 'AKG', 'Grounded']
# ['9 Air', '9 에어', 'AQ', 'JYH', 'Active']
# ['9G Rail Limited', '9G 레일', '9G', '', 'Grounded']
# ['AA 767, LLC', 'aa 767', '7Q', '', 'Active']
# ['AAA - Air Alps Aviation Ges.M.B.H.', 'AAA - 에어알프스 항공', 'A6', 'LPV', 'Grounded']
# ['AB Aviation', 'AB 항공', 'Y6', 'CYK', 'Grounded']
# ['AB Aviation', 'AB 항공', 'Y6', '', 'Active']
# ['Ababeel Aviation', '아바빌항공', '', 'BBE', 'Active']
# ['Abaete Linhas Aereas', '아바에테 리나스 아에레스', '', 'ABJ', 'Active']
# ['Aban Air', '아반 에어', 'K5', 'ABE', 'Grounded']
# ['Abas', '아바스', '', 'MRP', 'Grounded']
# ['Abc Aerolineas (Interjet)', 'Abc 아에로리나스', '4O', '', 'Active']
# ['Abc Air Hungary Ltd', 'ABC 에어헝가리', '', 'AHU', 'Grounded']
# ['ABC Bedarfsflug Gmbh', 'ABC 베다피쉬플러그', '', 'FTY', 'Grounded']
# ['Abelag Aviation', '아발렉 에비에이션', 'W9', 'AAB', 'Grounded']
# ['Aberdair Aviation Limited', '아베르데어 에비에이션', '', 'BDV', 'Active']
# ['Abidjan Air Cargo', '아비장에어카고', '', 'ADJ', 'Grounded']
# ['Aboitiz Air Transport Corporation', '아보이티즈항공운송주식회사', '', 'BOI', 'Grounded']
# ['Aboriginal Air Services', '애브오리지널에어서비스', 'I8', '', 'Active']
# ['Abs Jets', 'Abs 제트', '', 'ABP', 'Active']
# ['Absolute Flight Services (Pty) Ltd', '앱설루트 플라이트 서비스', '', 'COI', 'Grounded']
# ['Abu Dhabi Aviation', '아부다비항공', 'MO', 'AXU', 'Grounded']
# ['ABX Air', 'ABX 에어', 'GB', 'ABX', 'Active']
# ['ACA-Ancargo Air Sociedade de Transporte de Carga Lda', '앙카고화물', '', 'NCL', 'Grounded']
# ['Academy Airlines', '아카데미 에어라인', '', 'ACD', 'Grounded']
# ['Accessair', '어세스에어', '', 'CYD', 'Grounded']
# ['Ace Air', '에이스 항공', '', 'ATZ', 'Grounded']
# ['Acef - Transportes Aereos E Cargas, Lda.', 'Acef - 항공화물운송', '', 'CFM', 'Grounded']
# ['ACG Air Cargo Germany GmbH', 'ACG 독일에어카고', '6U', 'ACX', 'Grounded']
# ['Acm Air Charter Gmbh', 'Acm 에어챠터', '', 'BVR', 'Grounded']
# ['Acm Aviation', 'Acm 에비에이션', '', 'BJT', 'Grounded']
# ['Act International Airlines DBA Texas Airways', '액트 인터내셔널 에어라인 - 텍사스 에어웨이', '', 'CWT', 'Grounded']
# ['Action Air', '악티온 에어', '', 'ORS', 'Grounded']
# ['Action Airlines', '액션 에어라인', '', 'AXQ', 'Grounded']
# ['Active Aero Charter Inc', '액티브에어로챠터', '', 'AVR', 'Grounded']
# ['Acvila Air-Romanian Carrier', '악빌랴 에어-루마니아항공사', '', 'RRM', 'Grounded']
# ['Ad Aviation Limited', 'AD 항공', 'V6', 'VUE', 'Grounded']
# ['Ada Air', '아다 에어', 'ZY', 'ADE', 'Grounded']
# ['Addis Air Cargo Services P.L.C.', '아디스항공화물서비스', '', 'DSC', 'Grounded']
# ['Addis Airlines Plc', '애디스 에어라인', '', 'DDS', 'Grounded']
# ['Adefa, S.A.', 'Adefa', '', 'ADF', 'Grounded']
# ['Adi Shuttle Group, Llc ', 'ADI 셔틀 그룹', '', 'TEC', 'Grounded']
# ['Adler Aviation Ltd', '앨더 에비에이션', '', 'SWH', 'Grounded']
# ['Administracion De Aeropuertos Y Servicios Auxiliares A La', '어드미니스트레이션 드 에어로부에르토스', '', 'XXV', 'Grounded']
# ['Adria Airways', '아드리아 항공사', 'JP', 'ADR', 'Grounded']
# ['Adria Airways Switzerland', '다윈항공', 'F7', '', 'Grounded']
# ['Advance Aviation Services', '어드밴스 항공서비스', '', 'XTJ', 'Grounded']
# ['Advanced Flight Training Ltd', '어드벤스 플라이트 트레이닝', '', 'ADV', 'Grounded']
# ['Adventia', '어드벤티아', '', 'DVN', 'Grounded']
# ['Adygeya Airlines', '아디게야 에어라인', '', 'RDD', 'Grounded']
# ['AeBal (Aerolineas de Baleares )', '에어발', 'DF', '', 'Grounded']
# ['Aeg Aviation Services ', 'AEG 에비에이션 서비스', '', 'EBS', 'Grounded']
# ['Aegean Airlines', '에게안항공', 'A3', 'AEE', 'Active']
# ['Aeolus Air', '에올러스 항공', '', 'AAZ', 'Active']
# ['Aer Caribe', '에어카리브', '', 'ACL', 'Grounded']
# ['Aer Caribe Peru', '페루에어카리브', '', 'CPR', 'Active']
# ['Aer Lingus', '에어링거스', 'EI', 'EIN', 'Active']
# ['Aeralp', '아렐프', '', 'ALS', 'Grounded']
# ['AerCaribe', '에어카리베', 'JK', 'ACL', 'Active']
# ['Aerea Flying Training Organization , S.A.', '아에레 플라잉 트레이닝 오가나이제이션', '', 'ADG', 'Grounded']
# ['Aerea Transportes Aereos Del Pacifico', '델 퍼시픽 에어트랜스포츠', '', 'TAF', 'Grounded']
# ['Aereo Cabo', '아에로 카보', '', 'CBV', 'Grounded']
# ['Aereo Calafia', '칼라피아항공', 'A7', 'CFV', 'Active']
# ['Aereo Ruta Maya', '에어로 루타 마야', '', 'MMG', 'Grounded']
# ['Aereo Taxi Autlan', '아우틀란 에어택시', '', 'TLD', 'Grounded']
# ['Aereo Taxi Paraza', '아에로 택시 파라자', '', 'PZA', 'Grounded']
# ['Aereo Transportes Los Angeles De America', '로스엔젤레스 아메리카항공운송', '', 'AGI', 'Grounded']
# ['Aereo Wwg.', '에어로 WWG', '', 'WWG', 'Grounded']
# ['Aereos Pacifico', '아에로 퍼시피코', '', 'TFO', 'Grounded']
# ['Aereosaba', '아에로사바', '', 'ESB', 'Grounded']
# ['Aereotaxis', '아에로택시스', '', 'TXI', 'Grounded']
# ['Aereotuy', '에레오투이', 'L4', '', 'Active']
# ['AERFI Group plc', 'AERFI 그룹 plc', '', 'AGP', 'Grounded']
# ['Aerial Surveys (1980) Ltd', '에어리얼 서베이 1980', '', 'SUY', 'Grounded']
# ['Aerial Transit Company', '에어리얼 트린짓', '', 'AEZ', 'Grounded']
# ['Aeriantur-M', '아리안트루-M', '', 'MBV', 'Grounded']
# ['Aeris Gestion S.L.', '아에리스 제스티옹', '', 'RIS', 'Grounded']
# ['Aermarche', '아에르마체', '', 'MMC', 'Grounded']
# ['Aero (Nigeria)', '에어라 나이지리아', 'NG', 'NIG', 'Active']
# ['Aero 1 Prop-Jet', '에어로 1 프롭-제트', '', 'SSM', 'Grounded']
# ['Aero Africa', '에어로아프리카', '', 'RFC', 'Grounded']
# ['Aero Air, Llc', '에어로 에어', '', 'WIL', 'Grounded']
